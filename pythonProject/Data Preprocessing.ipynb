# %%
import pandas as pd
import os

def read_parquet_files(folder_path):
    # Get a list of all files in the folder
    files = os.listdir(folder_path)

    # Filter the list to include only parquet files
    parquet_files = [f for f in files if f.endswith('.parquet')]

    # Dictionary to hold dataframes
    dataframes = {}

    # Read each parquet file into a dataframe and store in the dictionary
    for file in parquet_files:
        file_path = os.path.join(folder_path, file)
        df_name = os.path.splitext(file)[0]
        dataframes[df_name] = pd.read_parquet(file_path)
    
    return dataframes

def display_heads(dataframes):
    for name, df in dataframes.items():
        print(f"Head of dataframe '{name}':")
        print(df.head(), "\n")
        
def display_sorted_column_names(dataframes):
    for name, df in dataframes.items():
        sorted_columns = sorted(df.columns.tolist())
        print(f"Sorted columns in dataframe '{name}':")
        print(sorted_columns, "\n")
        
def create_columns_overview(dataframes):
    columns_data = {}

    for name, df in dataframes.items():
        sorted_columns = sorted(df.columns.tolist())
        columns_data[name] = sorted_columns

    # Convert the dictionary to a DataFrame
    columns_df = pd.DataFrame.from_dict(columns_data, orient='index').transpose()

    return columns_df

def convert_parquet_to_csv(folder_path):
    # Get a list of all files in the folder
    files = os.listdir(folder_path)

    # Filter the list to include only parquet files
    parquet_files = [f for f in files if f.endswith('.parquet')]

    # Loop through each parquet file and convert it to CSV
    for file in parquet_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_parquet(file_path)
        
        # Define the output CSV file path
        csv_file_path = os.path.splitext(file_path)[0] + '.csv'
        
        # Save the dataframe to CSV
        df.to_csv(csv_file_path, index=True)
        print(f"Converted {file} to CSV.")

# %%
# Specify the path to the folder containing parquet files
folder_path = f'C:\\Users\sl3421\OneDrive - University College London\\UCL\PhD project\Boiler Data Analysis\Sample Dataset'

# Read parquet files and store in dataframes
dataframes = read_parquet_files(folder_path)

# %%
# Display the head of each dataframe
display_heads(dataframes)
# Out:
# Head of dataframe '_+xS65LR2RfO5oWppaAk1A==.asfreqffill.2min.snappy':
#                            ChBlock   SysPrimT  BCM_VersionNr  HwThermDisinf  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00      1.0  71.099998            0.0            0.0
# 2021-07-24 00:02:00+00:00      1.0  70.599998            0.0            0.0
# 2021-07-24 00:04:00+00:00      1.0  70.099998            0.0            0.0
# 2021-07-24 00:06:00+00:00      1.0  69.800003            0.0            0.0
# 2021-07-24 00:08:00+00:00      1.0  69.300003            0.0            0.0
#
#                                              Brand  DataLoss  FaultLock  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  No brand identification       1.0        0.0
# 2021-07-24 00:02:00+00:00  No brand identification       1.0        0.0
# 2021-07-24 00:04:00+00:00  No brand identification       1.0        0.0
# 2021-07-24 00:06:00+00:00  No brand identification       1.0        0.0
# 2021-07-24 00:08:00+00:00  No brand identification       1.0        0.0
#
#                            MinBurnLoad  ChargePump  ChActive  ...  \
# datetime[](datetime)                                          ...
# 2021-07-24 00:00:00+00:00         29.0         0.0       0.0  ...
# 2021-07-24 00:02:00+00:00         29.0         0.0       0.0  ...
# 2021-07-24 00:04:00+00:00         29.0         0.0       0.0  ...
# 2021-07-24 00:06:00+00:00         29.0         0.0       0.0  ...
# 2021-07-24 00:08:00+00:00         29.0         0.0       0.0  ...
#
#                            PumpPostTime  Oil_Burner  HwHeated         RetT  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00           3.0         0.0       0.0 -3276.800049
# 2021-07-24 00:02:00+00:00           3.0         0.0       0.0 -3276.800049
# 2021-07-24 00:04:00+00:00           3.0         0.0       0.0 -3276.800049
# 2021-07-24 00:06:00+00:00           3.0         0.0       0.0 -3276.800049
# 2021-07-24 00:08:00+00:00           3.0         0.0       0.0 -3276.800049
#
#                            CuTyp  ClipInRSSIMin  BoilSerialNo_BCD  ChActProg  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  HTIII            0.0          16091463        1.0
# 2021-07-24 00:02:00+00:00  HTIII            0.0          16091463        1.0
# 2021-07-24 00:04:00+00:00  HTIII            0.0          16091463        1.0
# 2021-07-24 00:06:00+00:00  HTIII            0.0          16091463        1.0
# 2021-07-24 00:08:00+00:00  HTIII            0.0          16091463        1.0
#
#                                        HwSys  CurFaultCode
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  Instant_hot_water          None
# 2021-07-24 00:02:00+00:00  Instant_hot_water          None
# 2021-07-24 00:04:00+00:00  Instant_hot_water          None
# 2021-07-24 00:06:00+00:00  Instant_hot_water          None
# 2021-07-24 00:08:00+00:00  Instant_hot_water          None
#
# [5 rows x 93 columns]
#
# Head of dataframe '_0oWZFR05w3m9GAywRNnRQ==.asfreqffill.2min.snappy':
#                            CodePlug  NomMaxPowDHW  ChOpTime  HwCircPump  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00    1412.0          30.0  176760.0         0.0
# 2021-07-24 00:02:00+00:00    1412.0          30.0  176760.0         0.0
# 2021-07-24 00:04:00+00:00    1412.0          30.0  176760.0         0.0
# 2021-07-24 00:06:00+00:00    1412.0          30.0  176760.0         0.0
# 2021-07-24 00:08:00+00:00    1412.0          30.0  176760.0         0.0
#
#                            TokenICom  PrimTSet  FanRpm  PowSet  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00        0.0       5.0     0.0     0.0
# 2021-07-24 00:02:00+00:00        0.0       5.0     0.0     0.0
# 2021-07-24 00:04:00+00:00        0.0       5.0     0.0     0.0
# 2021-07-24 00:06:00+00:00        0.0       5.0     0.0     0.0
# 2021-07-24 00:08:00+00:00        0.0       5.0     0.0     0.0
#
#                            CurFaultCauseC  TurbineDelay  ...  \
# datetime[](datetime)                                     ...
# 2021-07-24 00:00:00+00:00           203.0           0.5  ...
# 2021-07-24 00:02:00+00:00           203.0           0.5  ...
# 2021-07-24 00:04:00+00:00           203.0           0.5  ...
# 2021-07-24 00:06:00+00:00           203.0           0.5  ...
# 2021-07-24 00:08:00+00:00           203.0           0.5  ...
#
#                            HwActive[bool](float32)  HwDetInt  BoilOpTime  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00                      0.0       0.0   1654540.0
# 2021-07-24 00:02:00+00:00                      0.0       0.0   1654540.0
# 2021-07-24 00:04:00+00:00                      0.0       0.0   1654540.0
# 2021-07-24 00:06:00+00:00                      0.0       0.0   1654540.0
# 2021-07-24 00:08:00+00:00                      0.0       0.0   1654540.0
#
#                                   RetT PumpPostTime  WatPress  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00 -3276.800049          3.0      -0.1
# 2021-07-24 00:02:00+00:00 -3276.800049          3.0      -0.1
# 2021-07-24 00:04:00+00:00 -3276.800049          3.0      -0.1
# 2021-07-24 00:06:00+00:00 -3276.800049          3.0      -0.1
# 2021-07-24 00:08:00+00:00 -3276.800049          3.0      -0.1
#
#                                 BoilSerialNo_ASCII  ClipInRSSIMax ChViaEMS  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  55701230000097733600005            0.0      1.0
# 2021-07-24 00:02:00+00:00  55701230000097733600005            0.0      1.0
# 2021-07-24 00:04:00+00:00  55701230000097733600005            0.0      1.0
# 2021-07-24 00:06:00+00:00  55701230000097733600005            0.0      1.0
# 2021-07-24 00:08:00+00:00  55701230000097733600005            0.0      1.0
#
#                            CurFaultCode
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00          None
# 2021-07-24 00:02:00+00:00          None
# 2021-07-24 00:04:00+00:00          None
# 2021-07-24 00:06:00+00:00          None
# 2021-07-24 00:08:00+00:00          None
#
# [5 rows x 99 columns]
#
# Head of dataframe '_1OIjYrZLTWNXdoxIzyhRQ==.asfreqffill.2min.snappy':
#                            HwThermDisinf  ChSwitch ClipInSWTyp  Maint  RthYS  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00            0.0      -1.0  Product_FW    0.0    0.0
# 2021-07-24 00:02:00+00:00            0.0      -1.0  Product_FW    0.0    0.0
# 2021-07-24 00:04:00+00:00            0.0      -1.0  Product_FW    0.0    0.0
# 2021-07-24 00:06:00+00:00            0.0      -1.0  Product_FW    0.0    0.0
# 2021-07-24 00:08:00+00:00            0.0      -1.0  Product_FW    0.0    0.0
#
#                            NomMaxPowCH[kW](float32)  ChViaSwitch  HwDayFunc  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00                      42.0          0.0        1.0
# 2021-07-24 00:02:00+00:00                      42.0          0.0        1.0
# 2021-07-24 00:04:00+00:00                      42.0          0.0        1.0
# 2021-07-24 00:06:00+00:00                      42.0          0.0        1.0
# 2021-07-24 00:08:00+00:00                      42.0          0.0        1.0
#
#                                              Brand  2ndBurnOpTime  ...  \
# datetime[](datetime)                                               ...
# 2021-07-24 00:00:00+00:00  No brand identification            0.0  ...
# 2021-07-24 00:02:00+00:00  No brand identification            0.0  ...
# 2021-07-24 00:04:00+00:00  No brand identification            0.0  ...
# 2021-07-24 00:06:00+00:00  No brand identification            0.0  ...
# 2021-07-24 00:08:00+00:00  No brand identification            0.0  ...
#
#                            ChViaEMS  HwHeated  FaultBlock  ServM         RetT  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00       0.0       0.0         0.0    0.0 -3276.800049
# 2021-07-24 00:02:00+00:00       0.0       0.0         0.0    0.0 -3276.800049
# 2021-07-24 00:04:00+00:00       0.0       0.0         0.0    0.0 -3276.800049
# 2021-07-24 00:06:00+00:00       0.0       0.0         0.0    0.0 -3276.800049
# 2021-07-24 00:08:00+00:00       0.0       0.0         0.0    0.0 -3276.800049
#
#                                        BoilNameHT3  MinBurnLoad  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  Greenstar 42CDi Classic         27.0
# 2021-07-24 00:02:00+00:00  Greenstar 42CDi Classic         27.0
# 2021-07-24 00:04:00+00:00  Greenstar 42CDi Classic         27.0
# 2021-07-24 00:06:00+00:00  Greenstar 42CDi Classic         27.0
# 2021-07-24 00:08:00+00:00  Greenstar 42CDi Classic         27.0
#
#                            HwTOutlet[degC](float32)  HwNoStart  CurFaultCode
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00                      28.9     6040.0          None
# 2021-07-24 00:02:00+00:00                      28.9     6040.0          None
# 2021-07-24 00:04:00+00:00                      28.9     6040.0          None
# 2021-07-24 00:06:00+00:00                      28.9     6040.0          None
# 2021-07-24 00:08:00+00:00                      28.9     6040.0          None
#
# [5 rows x 93 columns]
#
# Head of dataframe '_4prOCQSUpw6IwsXARE9zA==.asfreqffill.2min.snappy':
#                            PumpPostTime  CurFaultCauseC  ServY  HwSetReach  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00           3.0           203.0    9.0         1.0
# 2021-07-24 00:02:00+00:00           3.0           203.0    9.0         1.0
# 2021-07-24 00:04:00+00:00           3.0           203.0    9.0         1.0
# 2021-07-24 00:06:00+00:00           3.0           203.0    9.0         1.0
# 2021-07-24 00:08:00+00:00           3.0           203.0    9.0         1.0
#
#                           BoilNameHT3  ActPow[%](float32)  Maint  MinBurnLoad  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  2020202035                 0.0    0.0         29.0
# 2021-07-24 00:02:00+00:00  2020202035                 0.0    0.0         29.0
# 2021-07-24 00:04:00+00:00  2020202035                 0.0    0.0         29.0
# 2021-07-24 00:06:00+00:00  2020202035                 0.0    0.0         29.0
# 2021-07-24 00:08:00+00:00  2020202035                 0.0    0.0         29.0
#
#                                 BoilSerialNo_ASCII  HwActProg  ... Oil_Burner  \
# datetime[](datetime)                                           ...
# 2021-07-24 00:00:00+00:00  55703090000008718690981        1.0  ...        0.0
# 2021-07-24 00:02:00+00:00  55703090000008718690981        1.0  ...        0.0
# 2021-07-24 00:04:00+00:00  55703090000008718690981        1.0  ...        0.0
# 2021-07-24 00:06:00+00:00  55703090000008718690981        1.0  ...        0.0
# 2021-07-24 00:08:00+00:00  55703090000008718690981        1.0  ...        0.0
#
#                            2ndBurnOpTime             BoilNameCus  ChMaxPow  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00            0.0  Greenstar 30Si Compact     100.0
# 2021-07-24 00:02:00+00:00            0.0  Greenstar 30Si Compact     100.0
# 2021-07-24 00:04:00+00:00            0.0  Greenstar 30Si Compact     100.0
# 2021-07-24 00:06:00+00:00            0.0  Greenstar 30Si Compact     100.0
# 2021-07-24 00:08:00+00:00            0.0  Greenstar 30Si Compact     100.0
#
#                            GasBurn  ChSwitch  ClipInRSSIMin  HwTSet  HwOpTime  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00      1.0      -1.0            0.0    60.0   79852.0
# 2021-07-24 00:02:00+00:00      1.0      -1.0            0.0    60.0   79852.0
# 2021-07-24 00:04:00+00:00      1.0      -1.0            0.0    60.0   79852.0
# 2021-07-24 00:06:00+00:00      1.0      -1.0            0.0    60.0   79852.0
# 2021-07-24 00:08:00+00:00      1.0      -1.0            0.0    60.0   79852.0
#
#                            ChNoStart
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00    58129.0
# 2021-07-24 00:02:00+00:00    58129.0
# 2021-07-24 00:04:00+00:00    58129.0
# 2021-07-24 00:06:00+00:00    58129.0
# 2021-07-24 00:08:00+00:00    58129.0
#
# [5 rows x 98 columns]
#
# Head of dataframe '_5LR3FGIZAZ6WM2Ub9WWfg==.asfreqffill.2min.snappy':
#                            ClipInRSSIMin  HwOpTime  ChBlock  Maint  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00            0.0   75527.0      1.0    0.0
# 2021-07-24 00:02:00+00:00            0.0   75527.0      1.0    0.0
# 2021-07-24 00:04:00+00:00            0.0   75527.0      1.0    0.0
# 2021-07-24 00:06:00+00:00            0.0   75527.0      1.0    0.0
# 2021-07-24 00:08:00+00:00            0.0   75527.0      1.0    0.0
#
#                            BoilOpTime  HwTSet  ChActProg  PumpPostTime  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00   3974929.0    53.0        1.0           3.0
# 2021-07-24 00:02:00+00:00   3974929.0    53.0        1.0           3.0
# 2021-07-24 00:04:00+00:00   3974929.0    53.0        1.0           3.0
# 2021-07-24 00:06:00+00:00   3974929.0    53.0        1.0           3.0
# 2021-07-24 00:08:00+00:00   3974929.0    53.0        1.0           3.0
#
#                            TokenClipIn  BoilProdDateHTIII  ...  ClipInSWTyp  \
# datetime[](datetime)                                       ...
# 2021-07-24 00:00:00+00:00          1.0           130812.0  ...   Product_FW
# 2021-07-24 00:02:00+00:00          1.0           130812.0  ...   Product_FW
# 2021-07-24 00:04:00+00:00          1.0           130812.0  ...   Product_FW
# 2021-07-24 00:06:00+00:00          1.0           130812.0  ...   Product_FW
# 2021-07-24 00:08:00+00:00          1.0           130812.0  ...   Product_FW
#
#                            ServD  CurFaultCauseC  ServBoilOpM  ChargePump  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00    0.0             0.0          0.0         0.0
# 2021-07-24 00:02:00+00:00    0.0             0.0          0.0         0.0
# 2021-07-24 00:04:00+00:00    0.0             0.0          0.0         0.0
# 2021-07-24 00:06:00+00:00    0.0             0.0          0.0         0.0
# 2021-07-24 00:08:00+00:00    0.0             0.0          0.0         0.0
#
#                            ExtCutOff  ChViaSwitch  ThermDisinfSet  DataLoss  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00        0.0          0.0            70.0       NaN
# 2021-07-24 00:02:00+00:00        0.0          0.0            70.0       NaN
# 2021-07-24 00:04:00+00:00        0.0          0.0            70.0       NaN
# 2021-07-24 00:06:00+00:00        0.0          0.0            70.0       NaN
# 2021-07-24 00:08:00+00:00        0.0          0.0            70.0       NaN
#
#                            CurFaultCode
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00          None
# 2021-07-24 00:02:00+00:00          None
# 2021-07-24 00:04:00+00:00          None
# 2021-07-24 00:06:00+00:00          None
# 2021-07-24 00:08:00+00:00          None
#
# [5 rows x 93 columns]
#
# Head of dataframe '_7dhbiWvHfzGRItv7TwkMg==.asfreqffill.2min.snappy':
#                            AntiFastCycTime  ChActProg  ServY  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00              5.0        1.0   14.0
# 2021-07-24 00:02:00+00:00              5.0        1.0   14.0
# 2021-07-24 00:04:00+00:00              5.0        1.0   14.0
# 2021-07-24 00:06:00+00:00              5.0        1.0   14.0
# 2021-07-24 00:08:00+00:00              5.0        1.0   14.0
#
#                            NomMaxPowCH[kW](float32)  ClipInRSSIMin  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00                      24.0            0.0
# 2021-07-24 00:02:00+00:00                      24.0            0.0
# 2021-07-24 00:04:00+00:00                      24.0            0.0
# 2021-07-24 00:06:00+00:00                      24.0            0.0
# 2021-07-24 00:08:00+00:00                      24.0            0.0
#
#                           ClipInSWTyp  ChNoStart  ChargePump  HwDayFunc  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00  Product_FW    15560.0         0.0        1.0
# 2021-07-24 00:02:00+00:00  Product_FW    15560.0         0.0        1.0
# 2021-07-24 00:04:00+00:00  Product_FW    15560.0         0.0        1.0
# 2021-07-24 00:06:00+00:00  Product_FW    15560.0         0.0        1.0
# 2021-07-24 00:08:00+00:00  Product_FW    15560.0         0.0        1.0
#
#                            CurFaultCauseC  ...  HwTSet    BoilSerialNo_BCD  \
# datetime[](datetime)                       ...
# 2021-07-24 00:00:00+00:00           203.0  ...    48.0  323930313233303030
# 2021-07-24 00:02:00+00:00           203.0  ...    48.0  323930313233303030
# 2021-07-24 00:04:00+00:00           203.0  ...    48.0  323930313233303030
# 2021-07-24 00:06:00+00:00           203.0  ...    48.0  323930313233303030
# 2021-07-24 00:08:00+00:00           203.0  ...    48.0  323930313233303030
#
#                            ChActive      OutTemp   SysPrimT ServReq  ChMaxPow  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00       0.0 -3276.800049  40.200001     0.0     100.0
# 2021-07-24 00:02:00+00:00       0.0 -3276.800049  40.099998     0.0     100.0
# 2021-07-24 00:04:00+00:00       0.0 -3276.800049  40.000000     0.0     100.0
# 2021-07-24 00:06:00+00:00       0.0 -3276.800049  39.900002     0.0     100.0
# 2021-07-24 00:08:00+00:00       0.0 -3276.800049  39.900002     0.0     100.0
#
#                            HwNoStart  DataLoss CurFaultCode
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00    54050.0       NaN         None
# 2021-07-24 00:02:00+00:00    54050.0       NaN         None
# 2021-07-24 00:04:00+00:00    54050.0       NaN         None
# 2021-07-24 00:06:00+00:00    54050.0       NaN         None
# 2021-07-24 00:08:00+00:00    54050.0       NaN         None
#
# [5 rows x 99 columns]
#
# Head of dataframe '_7In6XmEX+0XzNB98+QHKQ==.asfreqffill.2min.snappy':
#                            AntiFastCycTime  WatPress  FaultLock  TokenICom  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00              5.0      -0.1        0.0        0.0
# 2021-07-24 00:02:00+00:00              5.0      -0.1        0.0        0.0
# 2021-07-24 00:04:00+00:00              5.0      -0.1        0.0        0.0
# 2021-07-24 00:06:00+00:00              5.0      -0.1        0.0        0.0
# 2021-07-24 00:08:00+00:00              5.0      -0.1        0.0        0.0
#
#                            ClipInRSSIMin BoilNameHT3  BoilOpTime  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00            0.0  2020202038   1836068.0
# 2021-07-24 00:02:00+00:00            0.0  2020202038   1836068.0
# 2021-07-24 00:04:00+00:00            0.0  2020202038   1836068.0
# 2021-07-24 00:06:00+00:00            0.0  2020202038   1836068.0
# 2021-07-24 00:08:00+00:00            0.0  2020202038   1836068.0
#
#                           CurFaultDispC  ThermDisinfSet  ExtCutOff  ...  \
# datetime[](datetime)                                                ...
# 2021-07-24 00:00:00+00:00                          70.0        1.0  ...
# 2021-07-24 00:02:00+00:00                          70.0        1.0  ...
# 2021-07-24 00:04:00+00:00                          70.0        1.0  ...
# 2021-07-24 00:06:00+00:00                          70.0        1.0  ...
# 2021-07-24 00:08:00+00:00                          70.0        1.0  ...
#
#                            CodePlug RthYS  BurnNoStart  HwActProg  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00    1412.0   0.0      34076.0        1.0
# 2021-07-24 00:02:00+00:00    1412.0   0.0      34076.0        1.0
# 2021-07-24 00:04:00+00:00    1412.0   0.0      34076.0        1.0
# 2021-07-24 00:06:00+00:00    1412.0   0.0      34076.0        1.0
# 2021-07-24 00:08:00+00:00    1412.0   0.0      34076.0        1.0
#
#                            HwTOutlet[degC](float32)  HwDetInt  HwTSet  Ignit  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00                 43.400002       0.0    60.0    0.0
# 2021-07-24 00:02:00+00:00                 43.000000       0.0    60.0    0.0
# 2021-07-24 00:04:00+00:00                 42.599998       0.0    60.0    0.0
# 2021-07-24 00:06:00+00:00                 42.299999       0.0    60.0    0.0
# 2021-07-24 00:08:00+00:00                 41.900002       0.0    60.0    0.0
#
#                            DataLoss  CurFaultCode
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00       NaN          None
# 2021-07-24 00:02:00+00:00       NaN          None
# 2021-07-24 00:04:00+00:00       NaN          None
# 2021-07-24 00:06:00+00:00       NaN          None
# 2021-07-24 00:08:00+00:00       NaN          None
#
# [5 rows x 99 columns]
#
# Head of dataframe '_7JHiq_zGflwEoTPeImxEQ==.asfreqffill.2min.snappy':
#                            HwActProg  ChViaSwitch  ExtCutOff  BurnOpTime  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00        1.0          0.0        0.0    512858.0
# 2021-07-24 00:02:00+00:00        1.0          0.0        0.0    512858.0
# 2021-07-24 00:04:00+00:00        1.0          0.0        0.0    512858.0
# 2021-07-24 00:06:00+00:00        1.0          0.0        0.0    512858.0
# 2021-07-24 00:08:00+00:00        1.0          0.0        0.0    512858.0
#
#                            HwThermDisinf         RetT  Maint  ChViaEMS  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00            0.0 -3276.800049    0.0       0.0
# 2021-07-24 00:02:00+00:00            0.0 -3276.800049    0.0       0.0
# 2021-07-24 00:04:00+00:00            0.0 -3276.800049    0.0       0.0
# 2021-07-24 00:06:00+00:00            0.0 -3276.800049    0.0       0.0
# 2021-07-24 00:08:00+00:00            0.0 -3276.800049    0.0       0.0
#
#                            HwActive[bool](float32)  ChPumpMod  ...  HwOpTime  \
# datetime[](datetime)                                           ...
# 2021-07-24 00:00:00+00:00                      0.0        0.0  ...   99528.0
# 2021-07-24 00:02:00+00:00                      0.0        0.0  ...   99528.0
# 2021-07-24 00:04:00+00:00                      0.0        0.0  ...   99528.0
# 2021-07-24 00:06:00+00:00                      0.0        0.0  ...   99528.0
# 2021-07-24 00:08:00+00:00                      0.0        0.0  ...   99528.0
#
#                           ChSwitch  CuTyp  GasValMain  BoilNameCus  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00     -1.0  HTIII         0.0        11136
# 2021-07-24 00:02:00+00:00     -1.0  HTIII         0.0        11136
# 2021-07-24 00:04:00+00:00     -1.0  HTIII         0.0        11136
# 2021-07-24 00:06:00+00:00     -1.0  HTIII         0.0        11136
# 2021-07-24 00:08:00+00:00     -1.0  HTIII         0.0        11136
#
#                            ClipInRSSIMin  ServD  CodePlug  HwSetReach  \
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00            0.0    0.0   11136.0         1.0
# 2021-07-24 00:02:00+00:00            0.0    0.0   11136.0         1.0
# 2021-07-24 00:04:00+00:00            0.0    0.0   11136.0         1.0
# 2021-07-24 00:06:00+00:00            0.0    0.0   11136.0         1.0
# 2021-07-24 00:08:00+00:00            0.0    0.0   11136.0         1.0
#
#                            Oil_Burner
# datetime[](datetime)
# 2021-07-24 00:00:00+00:00         0.0
# 2021-07-24 00:02:00+00:00         0.0
# 2021-07-24 00:04:00+00:00         0.0
# 2021-07-24 00:06:00+00:00         0.0
# 2021-07-24 00:08:00+00:00         0.0
#
# [5 rows x 92 columns]

# %%
columns_overview_df = create_columns_overview(dataframes)
columns_overview_df.to_csv(folder_path+'\\columns_overview.csv')

# %%
convert_parquet_to_csv(folder_path)
# Out:
# Converted _+xS65LR2RfO5oWppaAk1A==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _0oWZFR05w3m9GAywRNnRQ==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _1OIjYrZLTWNXdoxIzyhRQ==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _4prOCQSUpw6IwsXARE9zA==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _5LR3FGIZAZ6WM2Ub9WWfg==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _7dhbiWvHfzGRItv7TwkMg==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _7In6XmEX+0XzNB98+QHKQ==.asfreqffill.2min.snappy.parquet to CSV.
# Converted _7JHiq_zGflwEoTPeImxEQ==.asfreqffill.2min.snappy.parquet to CSV.

# %%
import os
import pandas as pd
import shutil

def filter_rows_and_move_files(input_csv_path, source_folder, destination_folder, non_empty_columns, empty_columns):
    # 读取 CSV 文件
    df = pd.read_csv(input_csv_path, index_col=0)

    # 筛选某些列不为空且某些列为空的行
    filtered_df = df[df[non_empty_columns].notnull().all(axis=1) & df[empty_columns].isnull().all(axis=1)]

    # 获取符合条件的文件名列表
    matching_files = filtered_df.index.tolist()

    # 移动文件到新的文件夹
    for file_name in matching_files:
        source_file_path = os.path.join(source_folder, file_name)
        destination_file_path = os.path.join(destination_folder, file_name)
        if os.path.exists(source_file_path):
            shutil.copy(source_file_path, destination_file_path)
            print(f"Moved {file_name} to {destination_folder}")

# %%
non_empty_columns = ['NomMaxPowCH[kW](float32)', 'NomMaxPowDHW','HwSys','ChMaxPow']  # 替换为实际需要非空的列名
empty_columns = ['Cumulated_CH_total_electricity_consumption',	'Cumulated_DHW_total_electricity_consumption',	'Cumulated_DHW_fuel_consumption',	'Cumulated_CH_fuel_consumption',	'Ignit','HwNoStart','HwFlow[L/min](float32)',	'GasValMain',	'HwActive[bool](float32)',	'HwDetInt',	'HwHeated',	'ChActive',	'Fan','Flame',	'ActPow[%](float32)',	'ChPumpMod',	'FanRpm',	'FanRpmSet'
]      # 替换为实际需要为空的列名
filter_rows_and_move_files('D:\\2min-resample\MetaDataSeparation\\combined_unique_values.csv', 'D:\\2min-resample\MetaDataSeparation', 'D:\\2min-resample\MetaDataSeparation\MetaData Filtered', non_empty_columns, empty_columns)
# Out:
# Moved ++tIuzEatOjA1eOLG9Ey9Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +4IGI8kO80xWC1hZ797SLw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +8KRfSBu4OUWy3Nmn6xQDg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +9e1AhKPbCcnJQ9bSSkn9Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +AbEL65d09KYQ86STOajFA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +AhRwqohQEEmMZ5GIxIifg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +bgSBIgOiEKscDgB5dAVvg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +cm_03vhrPeG2ojncUfF0g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +dCArQqox4fhcRXe3LEgtQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +ECm_5xBCpDtXQ2AN_75xw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +flXTFV6kC6oYsBh3pYvgA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +Fo2oLTooyxml1S5RZmjWA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +GsMHxq6OIfvS6LHykgGZw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +Ik_Nsey0bJXbdt4mlojdQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +iYlkjyWRiqAPRHNHOjP6w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +lDcWuL+IryoFdlmoOH3+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +mPQUqR80fROWaOrEKvMnA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +nTg+SmuUmhJ0iPF7S45SQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +o7JnwMUvIQVsUN7RxdmVA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +ofrCDhPaADgIp8VUqEuSQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +oMphykhj0iuwq6Ah8RVIQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +onmCbNsIgU5ryo9mZsbhw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +R74bd7dcJW9tMFAigyQhg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +rV+E+jqXulnzL7x4P5N7A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +t1i7v_iDUw+YThA4xqLDA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +U5A4YEM2hUNlNdbaUgPpA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +uc2B5p7Bbxv84hg8186qQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +UyjZn_irvt3DzJOR0tzCQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +wngkiB8lQB6JlfHFS9eJQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +yDZdpgCL_kGV3jyJWcOCg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +yLN_1pTFtpvWa+eVTVrDQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +ZbQILpISR2vRif9iFL1cQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved +Zdhb9VFLhjzv1lXbzZJ2A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 02Y0jYdrdPS2gv79oL98wQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 030AuVMZEbfXP09_+EseHQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 03HXAZ3xQH5dMg1ZqAZ8qQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 051KyAT8XBCFjoIDTJGQ+Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 05RhG5x70L6wFZjZqziWQg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 08ommS+0721fF5z4LJVj5Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 09sgbYOCiBekJ+gxfy78qw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0aASPhS97x9ZtpK7Zo_4+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0CrcVgZYDwHsLLWO5P6AVg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0CRJVOKurnkimspUeY5jXg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0czWayuJMTGmk2K7rA3VqA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0dpEuRY+YQ1mGuCUtDxGdw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0D_siHa1_5PvuQwkO_NZDA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0eSzRc_Gyb2JzWsvd2jbCw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0f7O93dbnCcbb2+Ug0KT4w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0FSHTaOkAutpIgOTgj8xVQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0gIQsce52v8BmyAJRIv0Kw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0HCTnztXw8_GOHvwQuvYTA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0HKfySzcAsvZmWA1u3mdFw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0hYQPvnEtjkynnIc7Zjl9A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0HzT8lSiIE9Wgz3Nsf4xfw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0i3Yoc75ztxZDNu7YHx+Eg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0iLyps8EBFP3DiPHhLmtiQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0j5lUhBiENfVV_qIwNKtmQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0jHeLUY5U3vmcYgDGF3QBw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0KglMCo9TWM1_ylBc9Aycw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0KqoYQ0fAppgOIBr7F6d8w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0l0RZ7wqwI05NqxPTfEG0A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0LSGGncZA6KU90lxVAf_wA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0lw3yDypu4rsNLKEYuj9pA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0m+M3qoxgi1WJk9vREo8ow==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0mHRJZd4NYSrCZ53yN5Cag==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0noUMliC4KJQDfhYm6Tveg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0Np3meT145sbBXqfgJRbBg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0nRMLojsGzVjxzD2Y05ZKQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0nSBbqpT0v3HO5aa679CtQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0pLU2zJhXdkMgv9ICSAg8A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0qzna0qWVKfPNS_M4lAqEA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0rapfqGk6ooMe1h_9AsPHA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0Rea6Nv4b7QTnqAm1iM43Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0RgRUUL8Oj5Ax3DkRI6E4g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0Sbk_GJIgRra45unPC8yVQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0sF1Ad8n7o5ooZUvTFceXQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0Sw0GKmGkidHEbBqXcGEMA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0Tf2rrqV3uEVgaxFfKqH+A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0ujkxBPdf6_BMucNGKVVtA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0v1qEl3sM56QKPpd9x+Rtw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0VDdbs9X8DbBH5b531J2KQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0WGS0jdv2CkZ5TPx4FfwpQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0wVjJTazyQOiyLaVBzZNrg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0XErTs4_+1VlwX71v2ydCg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0XIoaJCWmrH5tAsyfedQzw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0XyA_Vnl4ReQk2ga4Lgf7w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0YIIkPf8JPQXzzzkme2SKg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0zu2AxTOEp8AePBoBgnRrg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 0ZYdNh6n8kKcVceuH2lISA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1+dwJRMpUGEeiK4UsmeKjQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1+nHQQuFxQumVEtLB95LHQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 10a7k9f21fbgvrNDa45xCw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 11HPH79cKMQJIghSmrMwNQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 12L49EBRZpY6QjDwH1Yy+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 12nc_u9AE_AV4QfRpR6xDg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 14Ld+BmHhE9Dz7Ghtcu_7Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 15fu2N29vfLRob+wHLlj+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 15JM60YSDVyIB1loc2myew==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 16AtOouuDENeBPAiANQw5w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 18TwmXl6gmWbLMqGaIGTcg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1A65gJML+7CH9J0WZJDv0w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1awYgV7TJxS9CM20CgplGg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1AzqDSg5OMPSTJ6kWXMcBw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Bb5iYGE0XXV5ICnLLOqcw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1c8OJnt9Me0491JzUsnskQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1c96TRwKhjMU4g9m+3CfCw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1CgLAKniEYH7BOvrzhx9Bg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1doGRqCQ0v4C_NWd+Y00Ag==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1DVIVixHCBLa4GC9dWWG5g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1E083LTc8kx4PlKG2lTrSg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1e22MN5jcFwRmQ231hh0yw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1g7cd3+8HIK8xjlZytbp3g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Gh01JaQrWDouuOXWLuHpQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1gLY8soV+CUcZ86898i0Yg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1hbS8AeYpgy02URK1BF9IQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Hf9Y1WwXfZpEAucBFKGuA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Hn+DVs7TEKUSYXTIvvTEA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1iduAewjkiXUKfL4rC38eg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1ig2Zqdhd3+B9VNGb2_xlw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1IO3qpK0IyD1JSKOC7kNsA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1jdtrnoFikAGGM8IkWcyeQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1jFBY3FNvunYLQiJXWfd8A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1jHD6mb9kwTi2W9xsOtXNQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1jSqnLJ6rvada+8i2KGACQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1LeimthgoYfcGbdoY8FFDA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1nV7MAMPo2_j1VPo9Q8OJA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1NwP5SSOp1OLSgjBC6kKsA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1nzcumtaaiEM4IgVcjoLMA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1O06vXKn825Riy_bUDn5tA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1ORtOu3ZhIVKUbYyJEA4dg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Q0e5YfsnbIyIvfAn_dssQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1qX9WlOUQnBGY+o+jPquNg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1r4GXwbysEeHXn5wv6FBfA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1r7FGpQCNs0ZMryxbAcWYg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Rhl83APcIZV9_7IwKn39w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1RWSR2R6CKgaimFaSUa0gg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1S7Uvu53o9U_w38ueHLtTQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1U0kaxcP0OG7+aSKXH2qDw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1veedjpsPp2MMB2xa2qP_w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1Vftbud2uiVV0+EyiNrIJA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1X1b+qeuwGWCLGN+BuXgng==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1xdfOomloR5DHCDdG9kFAQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1yEPPD1qgFtSkOokL6XDIg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1z2yKo16S0+t4RFq6rJnAA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1_OO_TCt3Xb55e1wuHM85Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 1_OvxiVurfI_ItSVJ17Kyg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2+wtM_9NfifdJZOZCoSUkQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2+Xpidh8dNeIMcmZxAVNQA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2053T20A5DLMpEHXrJOgiw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 21itP9NFsYT_2K69r2RU2w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 21SiD0Jp4AYtN_LslZT8EA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 23_+WxeeGIu1LBpmxl5Snw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 243iLqwD1_vIzxvvwuC+Xw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 245XhL75GC8pAJic28i2MA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 24BiOJRvm1MnLmk_2j7xCg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 25eh9VhJC1hGH2yk33jcKQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 25GDDJtFxbjisg0914Ytag==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 25HXn_yQgSeZeQECNRfQfA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 26KfH0ssPEw470JZ62KZKw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 27tpEZmQTI9K2Q+wQJPURQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 282lgPVxFJJG3mEHfmwHzA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 29qLW2PPh9ytiF_d6Ysbyw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2aAh1KfFS_4jIn6M01FZPQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2BUOx5BkNvioBoS3eAG5jg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2cAnmiFlzSJIBKnAuCSvSg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2csIbxWSWS0Sq9SR2m7mqQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2cVD_Gq4tvGbarcWlfWvgg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2Da9r33tUuqhT6re_3DgXw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2dSS9vJFs+83fhhCE_6yLg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2F1vr2ynpTkve3tzvpZMGA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2Fg0wS9C9DZ1_bySrSMjYg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2H7JS8uxS1fBk+kgtsMuZA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2HBR6ZPiTLdS8AcqBf20Bg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2IazyUitHAhyknwJLThu6Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2J2TweAgawiq+VBb4A6_rg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2jcBsZTboWPpm1DkLEIiOw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2JgZehhW6k0mXY1lf6QsbA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2k26+hSXa5DfKlhZwKXSvg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2Kp1hdzpKJ4BVmhWv0EK9Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2kqNbnaZRVpdKVNQVnZA6A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2n5hiVFs3JtMZuPFjORyFQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2Nmce2rTp2tM8vxRfXGvWA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2OUp2xuPDItPBDX4vs3NYA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2P1DubCUwVuUiItnru+Zpg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2Q68nqCrIU5CU8QztKQxkA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2q8STNgwgtzgLzVBt3k1ZA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2QLzqR5rsyMgI4oDKifY+Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2qPAqqCsUcSBxGtsKNSlaA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2RHxhItVDqNFV+3hOa9rXg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2sdInYqgb2yA76CJFl_y+Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2tIzy714gHxwvuY8Gi0UQw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2vppzDuGeTTwkshEJ67d4w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2W0Er4_KIa2fhUEpL5fiyw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2w22oV0Y1kfhlRgfLmRvsg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2WjCk3o+UbyS68KzBuEEcA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2WVDnB5K2EmuXUgLcYpXcw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2ZGP5Sh6PLf1ZPZtnVRN0w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2ZIA54byai4uCJ_CkrdzuA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 2_tsJqWwHHjOxik1R9Z2DA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3+oIb6ZmXA9wQuxlOh9_ZA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 311onSNSqZ+KynasAYkzRA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 34GngwJP4o8LjIVCpnwfug==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 34sql0ebUxmJkonIDzyqqw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 38aOFeWNTTPkklG8xXQr8g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 395_XJ6flrmDi9Nt46J8Vg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3aEWH5rkZl8yO4gjHNSaMQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3aGXqHj4ukyiZ5RjSbqGwQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3an4YRVvRAgSx6ZSb+is+w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3c9SHas9Qz13lXu4Xo+kWQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3cs9v6CncE2unHsttFNcAA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3deFiKy7sLRPObEKmAx8RA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3efpRwMcmbQbWNL_BoR6yg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3f0GQOe62VGiRdNOkRRETg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3FdbSdNJTjOVJ5VdoMw2nw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3fqztj6vkFihj3xjl8GPDg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3iKoZRQfQmiihEi7jVlghg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3Io7X1k7A51AcUZCZEPWAg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3JItQtlJ+3YMWhE7aLHuvA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3KhO_tLk8Wa_Mr3X0p_+rw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3KlM8RnYqZDMz+qKwWruIQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3lzUl6Oada31oILfj9w0cw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3mSt8ehW947+30qfUhZ3zQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3mZrnGnthw5scjM7Wy7gxA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3njGfQDayOE8Becd5zfyXw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3Oei9XxsuxRuXVcn07sLCg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3OQiq_sNF2kwXgIH_vwiPQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3p+KKlQ4Z1X_awv_SLyZzA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3pBGS2tF1p2n2BVa22CZbg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3plPHr_IBzpWqjLpWk8w2A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3PqR8Vmp_byPbVTQKOtYYA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3q4IX9V00I_PaVLbQxA1zw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3Qn05GzLf7HxoHGEwPuOeg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3SD3c1za3iGLetOkzprvgg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3SytMjTGDpGx54ldUJnPhA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3ukssVpeJjMvN4EEwG5bQg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3UxofgonUmLthMG_8WXzag==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3VhEhqK4xX+LJEotXNQC+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3vjPd38Cci5Gd46GVfQtPA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3xfjuyCxC1YoEEVzKfXWsg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3YX8qzqG_3APC9AbSbm98A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3zsNSSQDe0Y_RY4YkKOg+Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3zTBTwbqNPYkCg+WJtQGaw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3ztCjaZKm2QG75oDNb+NJg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3_+uc9Ps0CYwvgOgVC56sg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3_2FS5xTIWOfE6cBcK4EQQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 3_oMazbHd_MkxR1TSbhK6A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 42ahAnjRxJMpdqQ0VtHQuA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 43_3QdTDlbNNSKqos737iw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 44YIS79YUHOReJbObTfNzA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 456sKGWv1w+XZqqkU8wGsQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 45z5VNOZ1Dwbrp2Rgp8utQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 46p06cuZqkf2UjzkSXAY5Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 46QaB1Q+fr72f3VWp1TVuQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 46QJ_85_Skf+Mf3UVjPtJw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4A2x8u5zMOaDw4LBQPd6yA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4AR1PzyIA1UTtRhfqI4daw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4cmfF1LuLz4k27k64mdv6w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4cuCz+uMi180Ffejoxo0MA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4CwMp87mSlPwq92A6GcBAA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4DG2TMUpkI13vdi7bOTbSA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4e0+IdK1hNM1pan40Xkayg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4E6HyQHTXC4Yihc7VBv+1g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4e8PgToNbwaXM3qhZdV5vg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4iAvbsEBt0Urdd7vOKeDHg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4JD6iipNAOIFR9oC8lHfpA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4JVsBoLGDAEL4tHragePFg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4KXRMVu1xXns+nc+l9XWSA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4LsLtZlZppOpolL0n26IJg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4MoaormFiRVMEpniAFM3RQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4NNC+odLIG2Oa4YN55Q2Zw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4o6pgr3IBnJ4QQCEG1Ksgw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4OaBF4F_b1P36gJVRDqcZA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4oBxgNT3kcp6jNIMohfn8w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4otF22RlbjmXbIxjOxe1rA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4p8nr3UBVqFKNTiBYSQRuw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4R643ERVuT8aGRJ8fqYr+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4R_6V4uPA7UGry_mV3MwcA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4s4oiPLuu44gX6zrb7nfpw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4uenhYTW0zgf64J168hLPQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4vdGL8agdl173oRrlr9tag==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4vXmOlKPPtx1NOf66_K6FQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4VzMH1vN8MKOec5KlrldfQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4w5dASigJJpNwpamuLOifw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4Wf9TNNLC9XCVInVnggCPA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4wrI0U2VVVN7TuWD0RsQLw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4xD7roc1H5r9XCcoryB7NQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4xMj2+n9mNQPDDcKidSRKg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4xTWVz7d6uTNEVh59nkKDQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4ypGyRsB9ZMm6Dqbj6NxJA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4Z0XyI3JCYzq_oFZnX3cfg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4ZLBhhCgolf1FOBnzjOLTA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4zLjIJNMuZteXvivWo785A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4zR7JcXIo6p8q0cqkk_Bjw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 4zsHV8EsQC5MERm60vLgtQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 51XtKqOqcPLUJ8mJcYKkIg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 52MdZ9ZK+B0+vJ7WLlVDJA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 53gsidwnpmf0rMjRzeAkWw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 53vYzDmhkLbkf6E98KD1mg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 54dDNoxnvy0Q9vX6ddwtqA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 54QEJLYgqMzp0zVrHKxA3A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 558lVevNUTPnnQwk1b60dQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 55M1yqPf7vkWHUxRI6gJ5w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 56CfQwn2z9DUrx9kkH_Img==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 579u3l0SllaeG+8UdAE5eg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 57HU4AFZ60b4zT2_SfPeRg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 58MtXqEf1bT48CeXxtn1kg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 597xz9mmVkirU_agc+7keQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5ASGfrWvCijWIl2LOIqLHw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5BmQYnJ7O9YB40q+8oJaZw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5BQRiSp0GSVmTz+2y0j5nQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5bW21QANTZoAmk2pCZKZDw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5C83F6wblNf9yJEkDHsQIw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5CGOrXkITbtxm0HoVn0RSA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5cHMqqzzeTf02M2b5SgJqg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5cisb_+TXo+HxSO9hPFmfQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5CkyJ5TZ81gwLVWomKhwAw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5ckzOUiFlBgMWkhdG0wDXg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5cyvyEjcFhitYHcIgWHq1w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5fSVeVtv3+BDzUw6HGPmAA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5fV7UW8FbqPdELiU+EIR5A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5hPgukaH4dv3NfN2EtumuQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5i0k4to3TRJGViI5L+vK6A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5It5j9stjCy+NGQKI+zUAQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5jbSt2L31lH3LULhBvoesg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5K0l66bP9yDZHVFTMaSFBw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5K5OA6906i7oS1NBKjjJtQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5k7srrrRlxAGwlmD26DPZA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5KMZk_qd2NEXdzU0HAfBJw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5L1esBBZZDBEq5c6DxzKVQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5l9iTKkymLvVUHm33CZ5HA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5LmT9GM735+F415paO52vA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5LZjr+JWHgaAiOALeq9kqw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5MBZEFx58F93SqDFX7mMGw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5mqK3ql82JKvZK6xmZKcFg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5MtkKRyen7BXBlbGjFedPA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5MwHg_F5fImFoaG9vkicRQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5NhdQFrmapJK_XAzJaMxHA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5noRu9Q43KbyZ4tCQm4s2A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5nzz2MD+kLJa4C3Q26MqSA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5o4gX8VagAlf1su6IZmWMg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5O7o1C+CtPBZlLbE9mzVSQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5OtMHTdGF858M5h8qQ2odg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5QTUzBvCDyuo4dbu_ikR_A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5R0trj5Q9zWzXf5V8QwMYw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5Se1gNVMEl3pU48TROU7Qg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5tqLjYX8iId+Ha8pLegWzQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5uAg5Fz0c1Ve4NQ8gmlFGA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5uXrqeU1WI40s0SHa4clzA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5uy7seumgDt1AiLAjFdRqA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5V+5qkQ+CAzOu1mX_6izBQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5vR_mWfpEcVZhKbt6H2lMw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5WV5haMipJd40pVv1k+oYQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5xKadBgmwu_HgLyeZuj9qg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5zDZ0cJDnb9cvYlgJhUAVw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5zgYgU_P_MiY4tlgjckupQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5ZHEm0AmD8XjwmE0ZlID3A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 5ZW7maSHMIcKTaoAOFxssw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6+1r0ozTFJ5LCFEpnQZ+3g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 60g429+KYjkfbXDK08zkUg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 60h8+8GAYEkPxVzVjz4pPw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 60NlvUronkL4_1g+OM9p8w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 61PdaUP59WUG0yz5MOD1hg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 62AWX8Dj2Hy0DyRKmLN+Nw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 63fI_aoRnIRjhCRdPsoSXw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 66yoojFUFEAv0zdVpfOfCA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 67NTqJxB3qW7YkFhDbFE+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 68nlxTUUc6G1V4ZZ0n4cMw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 68Y70LLIIArtJX2TAtRpFQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 69IP4FCPmRTzS2VPJfA7fw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6ActSDZfJRnzpfl7a2GSzw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6Aeql4Mtssb7AhpCz0HbMw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6AVNNnkuze37t2xabWLlSA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6BiTmcT5PaaKg9HwgRg5Qg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6C+CFyYsJ4d4z+6FFvIWrg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6ddPTMKOLmv6QinY0VNWLw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6e2h+fGyuDcnZwLmM2TslQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6EReKAvIr_1qNBgETCDOIQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6f91iCub_vEcy7gvgerReg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6fbsWiryA67Pc+urmc0TnA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6fLBkFoGMSGL5AS8ecYkSg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6gIzHWmP+i8H70ap5pgP9w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6HBhiJyOPmjOt4UYIxqnQA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6hQU4GxJSEnTi0zY9VNuDQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6hVtxC2WZwCkVAdsLrC5fQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6HwZ58S24c6C6PR4LSrwJA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6i44VUG5L1yNul8uQncPGw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6i4rJ1Bj07D38Me0Guc4xQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6joGDagLjrosv9sXwDsqmg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6JUhSJH6RTqLxlFVwq_tRQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6Jx6kHCaiHsX6ajxHks1Nw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6K3vikYSWoI+4qjwaN9giQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6K4y+YFCUWrHzGAhffOmsg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6kKBUXqDal1H5je2LDbtyw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6l4qjdA0ySNeXFZomj0dhQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6Mj9FhMmgdFjZ2BAVAGk5A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6NuyRAk++OrNrVDv3WhbmA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6NZZgRet6DVXaVK+hm0JJw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6oc9H2AL8iVmZsnQbwpTvw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6p8AvSbQjavuC1QWYpZDqw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved 6PTgcfMKVNcoSSAzE2UnDA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# ...
# Moved Z4h9CvvAlYlFNSKUrf4z1w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z4X3vedsOumsi7tod2BZXw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z5sOxXCQGY9oJpLcKjBtoA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z5uvkoY+2V8y+OBxuxhB2w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z6knFBHpxaWuVlgErzFPIw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z7z3fGtwoMwTeA3_Nq0c8g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z7_yirRVTZ2rjin7kNRmSw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z8BI9K59PapMIxSUN_lNkw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z8eEFHxC71Fb6DUl5CfWig==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z8KvpSSlmc2fcSI5BnPfzQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z98fQimOFSyH5l64QeLOpw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z9B6wesdUf5c1esHX_RXNQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z9zkcJLD2hVWOUpzm7unrA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zA3ozReEsIpPgiozD1hnaQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zA9TRraNrSuoAJ_JSNE0qQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZaGTvlVrETIGHAhqraQ6oA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZB75rnmmTN4buzQ+B8V0aA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Zbb0CR+wGVNMreLzEjyDUA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Zbbj2oQ_W7nI6Dm0aZ2B8Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZbEJ9_YUJkDNZhkH__irTw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zbl8s80VwWO45n99wy4soA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZC3yQa96AdbcipWyXIIctg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZCBdrcFdgDPQakc2juoCVw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZCDnRkFez0VBo9AGZotS5w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zcEvsUezXjfJ60I+WIJp8Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZC_jG4nL+RpevGYzmXr9Wg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zDe4HmYYqjBnXLY_mrmQSQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZfFRdWN71zoCbXv53G_LRQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZFlKjIjEaJns1u27L7f13A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZG0hFDnIi_q7PXrjLacPhw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zg3lp_IQXKR0+7TG8Q4Fkg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zG_9cE+WO_GRka8Cij2k+Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zH5rrhTmtPnmhZfk5S6CUA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Zh7E9YNipwU_JA3XMgzQtw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zHo8YOtuBdnUJu_tR6MW1A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZHrMUNFJghHkJS0gmZQnkg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZhrNkuxh368xNJkj7L2NDA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zi3LsnynZ3TJQpQdz37kkg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zIhMP1QatGT8BWfH9j8u8A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zInZzOS+pqyZhmoPtWracA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zIqAVk0qdSW9b+EtDiLCTw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZjjBZLvA20QHW6g1loHgpQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zJnFGIwArXA+uxgwAu9i_Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zJPWnrx7bkYYWaPqTsG3Ug==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zJxGZtKhmyquexyQjGoMCw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZKiLyH4sCgc+ULevXh9uVA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZkKLtlyoaH7w1vnv12G21Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zl0yaSwZeHbiR4JOg+iSmg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZlppHi8rZ+rO1BoMxuKJ1Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Zm6YWvk9zYCAFoAi2NkR_A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZmA6HDkE4yHsJfjQe1MLOg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZmH_GvPpIz5lW63OEMPVkA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zmOYI5azzWXwmJfykTQrug==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZMQ76vA_zvGN9wWlecQ4cQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZMQjEUq0yo5BrPcKOAgprQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZmVnVp34BcKM5OxgjXWmpg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zok3CF2UsM8rwoPDh2_PxA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZOlJ6WSitf8C83mpn5O71w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zOOcf6URBImCtZPDE8YUtg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zpoPXpiXAPOZCfd8oVkrRw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zpx7aT66N5aC7LxGs7N_Kg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zqf3c_r2esrlHa0K3gdWFA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zqfWtGG8zsbrGbt9PUPARg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZQGiBMXQtNyWAkoWlzLExQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zQZNcqKHNgjAHjMIGdu9wA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zR0VP2TRb9wwYIz+2EQGSQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zRA9NVDo7Nk8KClt_RY4Hg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZRhU8F5Ts++lwns3hmY3PQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZrO9rlJlVZ8_4BCjhzvNNQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZRU2Z331mXn1ud_JXy6uuQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zRw9VIpD4A4VhVDd7IQWaw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZSHMdJBRgFSya53_6cEKFw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zsk6bX8_cR386mViJdhNww==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zSLsjK9WSzHKDN3ssQi7+w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZSMjU5XrJf8F6DLNC6I7sQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZSTNZUum0qeazoj4WiM4Ig==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZTS+F1pM6OEZR7AmmniuOA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ztuL52sglEYZ1Ba5p+Ws+g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Zu+vedGQZ_INx33LpLVKhw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zuipmEJMlclkkCb4V0vO_w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zUnLilIVshU0g1FwkokhyA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zv3puZHeK3a_g2hmYpL7bA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZvyCbbxE_MgLB0Z_TCBbPQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZwakDy2_f3FYXXrYA2R_GQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZwMGGAeFxjhIvGfHZ30sOA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZWTgMlUtOIptuRD2Czopqw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zWUV9AmlsQ3NY_ZLvn57uA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zX6jP5IDljMp9N5XGsJtEA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zXRMLvdvRR4uTmXLqjvffw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZY0T2g8A+_pDozNErIRFTg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved ZzCDu+ob4mKGibWAk1tu_Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved zzHgJjY5J9wxYOLvTSB1xg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z_GKAI5yIbTH1ANRJRkloQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z_kMybVmwB6xUqMjKY8vpQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved z_OLC+5lrmR57_9IzQ8L_A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved Z_UpwRY0bTtJwc3OMg5Rug==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _0oWZFR05w3m9GAywRNnRQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _4prOCQSUpw6IwsXARE9zA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _7dhbiWvHfzGRItv7TwkMg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _7In6XmEX+0XzNB98+QHKQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _7rp40k7pb8Cj8gNe5k+3w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _8hoxwZXGSVwn+PlbAC6KQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _8RX_AG6Hl5kKR0uRe+E9A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _9H3PahsJDXPpmJVL2OfQg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _az3kW3TkuauN_l43dhcNg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _daSW6zBvFkZIgmdfd0meQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _dWouoQ374FD24ZPmxv19A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _e30MG4nnzIAyOV6X223Qw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _ECh4KmLlJUq0GDfnSffRA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _EUCWupZkg81Li+5YkrOrg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _GW5eBn7Y448tvbh+1gtgg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _h6NdwqF_XocpwKir0DluA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _Hj0n0pdBWKfA0MUnV6IZA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _h_viHkcLbiJTXo4QbkwoA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _H_XBGF57drX0+B363JfXA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _i3XYtBfgNP1qNgILoNG_g==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _iVeRoojRihKsEmaZznlaw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _J7WSppKIwQM3UKeCV8NvQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _jsto47DYjuEHgItnaRSuA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _jVZ_RV8wBzfT0YR2zGC+w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _kuo_DCNzXeNYymcx7FzLw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _MKh9MAykjsmhWoY19QMAQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _PkmtPEvUTf4V2E54UrlCA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _unsfjYJ3kxFzlI4OKs3sQ==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _Wby7Tg2fbOS8wJrxvr6qg==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _wgB54VK9CXdUaEEuqooEw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _WXdjNz5yg4NaJJSo1yl4Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _x7gdC1LHckqlBfADDaQ1A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _xND7QKsaekRidy7AbYB2w==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _ycbv3_G1bxn37sPIEap6Q==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _yMLoQYpruYShBHZslrw9A==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _zIzimxCUIJ64ExnEsspMw==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered
# Moved _ZqejM7YIqPWJ95IY9O2iA==.asfreqffill.2min.snappy.parquet to D:\2min-resample\MetaDataSeparation\MetaData Filtered

# %%
import pandas as pd
import os
import shutil

def move_files_with_columns(source_folder, destination_folder, column_names):
    # Get a list of all files in the source folder
    files = os.listdir(source_folder)

    # Filter the list to include only parquet files
    parquet_files = [f for f in files if f.endswith('.parquet')]

    # Ensure the destination folder exists
    os.makedirs(destination_folder, exist_ok=True)

    # Initialize a counter
    count = 0

    # Iterate through each parquet file
    for file in parquet_files:
        file_path = os.path.join(source_folder, file)
        df = pd.read_parquet(file_path)
        
        # Check if all columns exist in the dataframe
        if all(col in df.columns for col in column_names):
            # Move the file to the destination folder
            shutil.move(file_path, os.path.join(destination_folder, file))
            count += 1

    return count

# Specify the path to the folder containing parquet files
source_folder = 'D:\\2min-resample\MetaDataSeparation\MetaData Filtered'
destination_folder = 'D:\\2min-resample\MetaDataSeparation\MetaData Filtered\With_RetT'
column_names = ['RetT','ChNoStart','HwFlow[L/min](float32)','ActPow[%](float32)','HwActive[bool](float32)','HwTOutlet[degC](float32)','ChActive','SysPrimT']

# Count the files with the specified column
count = move_files_with_columns(source_folder, destination_folder, column_names)
print(f"Number of files containing all the specified columns {column_names} moved: {count}")
# Out:
# Number of files containing all the specified columns ['RetT', 'ChNoStart', 'HwFlow[L/min](float32)', 'ActPow[%](float32)', 'HwActive[bool](float32)', 'HwTOutlet[degC](float32)', 'ChActive', 'SysPrimT'] moved: 1532
